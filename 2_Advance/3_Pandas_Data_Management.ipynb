# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# DataFrame Copy
df_original = df.copy()

# %%
df_altered = df_original

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
median_salary = df_altered['salary_year_avg'].median()


df_altered['salary_year_avg'] = df_altered.loc[:,'salary_year_avg'].fillna(median_salary)

# %%
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                1859875118416
# ID of df_altered:                 1859875118416
# Are the two dataframes the same?  True

# %%
df_original = df.copy()
df_altered = df_original.copy()

print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                1860397927312
# ID of df_altered:                 1859879160976
# Are the two dataframes the same?  False

# %%
median_salary = df_altered['salary_year_avg'].median()

# Filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
df.sample(n=5)
# Out:
#                   job_title_short                             job_title  \
# 63133                Data Analyst                          Data Analyst
# 574844       Senior Data Engineer  Senior Data Engineer, B2B Acceptance
# 606886               Data Analyst     Manager, Digital Analytics (L 09)
# 351755  Machine Learning Engineer           Machine Learning Specialist
# 233598             Data Scientist             Data Manager (H/F) | POEI
#
#             job_location                    job_via job_schedule_type  \
# 63133              Spain            via Trabajo.org         Full-time
# 574844       Atlanta, GA       via Visa - Talentify         Full-time
# 606886          Anywhere               via LinkedIn         Full-time
# 351755  Lisbon, Portugal          via Jobrapido.com         Full-time
# 233598   Puteaux, France  via Welcome To The Jungle         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 63133                False                      Spain 2023-09-09 06:26:22
# 574844               False  California, United States 2023-02-23 09:24:44
# 606886                True                      India 2023-04-18 09:13:24
# 351755               False                   Portugal 2023-01-28 00:03:38
# 233598               False                     France 2023-07-11 07:54:54
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 63133                    True                 False          Spain
# 574844                  False                  True  United States
# 606886                  False                 False          India
# 351755                  False                 False       Portugal
# 233598                  False                 False         France
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 63133         None              NaN              NaN
# 574844        None              NaN              NaN
# 606886        None              NaN              NaN
# 351755        None              NaN              NaN
# 233598        None              NaN              NaN
#
#                           company_name  \
# 63133                           Repsol
# 574844                            Visa
# 606886                       Synchrony
# 351755  HUK-COBURG Versicherungsgruppe
# 233598                   Datascientest
#
#                                                job_skills  \
# 63133                ['sql', 'sas', 'sas', 'r', 'python']
# 574844  ['nosql', 'python', 'cassandra', 'mysql', 'db2...
# 606886                      ['sql', 'sas', 'sas', 'word']
# 351755  ['python', 'azure', 'aws', 'pytorch', 'tensorf...
# 233598                                               None
#
#                                           job_type_skills
# 63133   {'analyst_tools': ['sas'], 'programming': ['sq...
# 574844  {'cloud': ['oracle'], 'databases': ['cassandra...
# 606886  {'analyst_tools': ['sas', 'word'], 'programmin...
# 351755  {'cloud': ['azure', 'aws'], 'libraries': ['pyt...
# 233598                                               None

# %%
df.sample(frac=0.1, replace=False)
# Out:
#               job_title_short  \
# 349454   Senior Data Engineer
# 297244          Data Engineer
# 659133           Data Analyst
# 578524  Senior Data Scientist
# 205985         Data Scientist
# ...                       ...
# 12255           Data Engineer
# 10243           Data Engineer
# 435896          Data Engineer
# 256378       Business Analyst
# 774239          Data Engineer
#
#                                                 job_title     job_location  \
# 349454    Senior Data Engineer (m/f/d) - Team Forecasting  Berlin, Germany
# 297244                                      Data Engineer    Liverpool, UK
# 659133   Data Analyst Automotive Hochvoltspeicher (m/w/d)  Munich, Germany
# 578524                      Senior Data Scientist (m/f/d)  Munich, Germany
# 205985                              IT - Data Scientist 4   Pittsburgh, PA
# ...                                                   ...              ...
# 12255                                       Data Engineer  San Borja, Peru
# 10243                             Team Lead Data Engineer   Moscow, Russia
# 435896  Jr. Intel Data Engineer - ETL | Cloud | Data W...      Rosslyn, VA
# 256378                                 Operations Analyst      New Zealand
# 774239                Data Engineer remote work Lithuania         Anywhere
#
#                    job_via job_schedule_type  job_work_from_home  \
# 349454        via LinkedIn         Full-time               False
# 297244        via LinkedIn         Full-time               False
# 659133       via Stepstone         Full-time               False
# 578524        via LinkedIn         Full-time               False
# 205985    via ZipRecruiter         Full-time               False
# ...                    ...               ...                 ...
# 12255       via BeBee Perú         Full-time               False
# 10243            via hh.ru         Full-time               False
# 435896  via Clearance Jobs         Full-time               False
# 256378     via Trabajo.org         Full-time               False
# 774239       via Adzuna.pl         Full-time                True
#
#                 search_location     job_posted_date  job_no_degree_mention  \
# 349454                  Germany 2023-09-21 23:26:24                   True
# 297244           United Kingdom 2023-12-14 17:13:27                   True
# 659133                  Germany 2023-06-12 10:38:57                   True
# 578524                  Germany 2023-12-22 09:18:19                  False
# 205985  New York, United States 2023-07-28 22:02:36                  False
# ...                         ...                 ...                    ...
# 12255                      Peru 2023-12-20 13:26:16                  False
# 10243                    Russia 2023-11-12 13:34:34                   True
# 435896  Illinois, United States 2023-02-01 16:49:24                   True
# 256378              New Zealand 2023-12-14 07:19:24                  False
# 774239                   Poland 2023-04-05 01:42:42                   True
#
#         job_health_insurance     job_country salary_rate  salary_year_avg  \
# 349454                 False         Germany        None              NaN
# 297244                 False  United Kingdom        None              NaN
# 659133                 False         Germany        None              NaN
# 578524                 False         Germany        None              NaN
# 205985                 False   United States        None              NaN
# ...                      ...             ...         ...              ...
# 12255                  False            Peru        None              NaN
# 10243                  False          Russia        None              NaN
# 435896                 False   United States        None              NaN
# 256378                 False     New Zealand        None              NaN
# 774239                 False          Poland        None              NaN
#
#         salary_hour_avg                       company_name  \
# 349454              NaN                               Flix
# 297244              NaN                            Matalan
# 659133              NaN                       Bertrandt AG
# 578524              NaN                        EGYM | DACH
# 205985              NaN                             V2Soft
# ...                 ...                                ...
# 12255               NaN                   Intercorp Retail
# 10243               NaN          билайн: ИТ, Data, Digital
# 435896              NaN                           Deloitte
# 256378              NaN  Te Whatu Ora - Health New Zealand
# 774239              NaN                  KLIENT jobdesk.pl
#
#                                                job_skills  \
# 349454  ['python', 'typescript', 'sql', 'scikit-learn'...
# 297244                               ['go', 'gcp', 'aws']
# 659133                         ['python', 'aws', 'azure']
# 578524      ['python', 'java', 'go', 'r', 'sql', 'nosql']
# 205985                                               None
# ...                                                   ...
# 12255                                           ['excel']
# 10243   ['scala', 'sql', 'postgresql', 'spark', 'hadoop']
# 435896  ['python', 'java', 'scala', 'r', 'sql', 'hadoo...
# 256378                                          ['react']
# 774239                                               None
#
#                                           job_type_skills
# 349454  {'libraries': ['scikit-learn', 'pandas', 'nump...
# 297244   {'cloud': ['gcp', 'aws'], 'programming': ['go']}
# 659133  {'cloud': ['aws', 'azure'], 'programming': ['p...
# 578524  {'programming': ['python', 'java', 'go', 'r', ...
# 205985                                               None
# ...                                                   ...
# 12255                        {'analyst_tools': ['excel']}
# 10243   {'databases': ['postgresql'], 'libraries': ['s...
# 435896  {'async': ['jira', 'confluence'], 'libraries':...
# 256378                           {'libraries': ['react']}
# 774239                                               None
#
# [78574 rows x 17 columns]
